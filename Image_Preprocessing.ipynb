# %%
import pandas as pd
import os
import glob as gb
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
TRAIN_DIR = "/content/drive/MyDrive/Colab-Project-Workspace/Datasets/train"
TEST_DIR = "/content/drive/MyDrive/Colab-Project-Workspace/Datasets/test"
BATCH_SIZE=64

# %%
for folder in os.listdir(TRAIN_DIR):
    files = gb.glob(pathname= str(TRAIN_DIR+ '/'+ folder + '/*.jpg'))   
    print(f'For training data, found {len(files)} in folder {folder}')
# Out:
# For training data, found 86 in folder Angry
# For training data, found 92 in folder Fear
# For training data, found 93 in folder Happy
# For training data, found 96 in folder Sad
# For training data, found 96 in folder Surprise

# %%
for folder in os.listdir(TEST_DIR):
    files = gb.glob(pathname= str(TEST_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For testing data, found {len(files)} in folder {folder}')
# Out:
# For testing data, found 86 in folder Angry
# For testing data, found 92 in folder Fear
# For testing data, found 93 in folder Happy
# For testing data, found 96 in folder Sad
# For testing data, found 96 in folder Surprise

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def view_random_image(target_dir, target_class):
    # We will view images from here
    target_folder = target_dir + target_class
    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder+'/'+random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis('off')
    print(f"Image shape {img.shape}")
   
    return img

# %%
class_names = ['Sad','Happy','Fear','Angry','Surprise']

# %%
plt.figure(figsize=(20,10))
for i in range(12):
    plt.subplot(3, 6, i+1)
    class_name = random.choice(class_names)
    img = view_random_image(target_dir="/content/drive/MyDrive/Colab-Project-Workspace/Datasets/train/", target_class=class_name)
# Out:
# Image shape (1131, 1698, 3)
# Image shape (330, 600, 3)
# Image shape (505, 348, 3)
# Image shape (819, 1024, 3)
# Image shape (597, 1063, 3)
# Image shape (1800, 1200, 3)
# Image shape (683, 1024, 3)
# Image shape (900, 600, 3)
# Image shape (1080, 1920, 3)
# Image shape (1160, 1300, 3)
# Image shape (532, 800, 3)
# Image shape (333, 500, 3)
